# %%
import pprint
import pandas as pd
import numpy as np
import os
import tqdm
import seaborn as sns
from tensorflow import keras
from tensorflow.keras.utils import plot_model
import tensorflow as tf
from scipy.signal import spectrogram
import matplotlib.pyplot as plt
from pipeline.utils import PrepareData, compare_plot
from pipeline import generate_model, get_initial_input
from sklearn.preprocessing import MinMaxScaler

# %%
def rejuste_index(lista_dfs):
    """Rejusta o index para o plot do RUL."""
    for index, df in enumerate(lista_dfs):
        if index == 0:
            df["index"] = df.index.tolist()
        else:
            shape_anterior = lista_dfs[index - 1]["index"].tail(1).values[0]
            df["index"] = np.arange(
                shape_anterior, df.shape[0] + shape_anterior
            )
        df["PREDICTION"] = df["PREDICTION"].apply(lambda x: 0 if x < 0 else x)


epochs = 30
train, test, label_train, label_test = get_initial_input()
model2, history = generate_model(
    train=train, label_train=label_train, epochs=epochs
)


plt.title("Learning Curves")
plt.xlabel("Epochs")
plt.ylabel("MSE")
plt.plot(range(1, epochs + 1), history.history["mse"], label="train")
plt.plot(range(1, epochs + 1), history.history["val_mse"], label="val")
plt.xticks(range(1, epochs + 1))
plt.legend()
plt.tight_layout()
plt.savefig("images/mse_val_train.png")

predict_rul_test = np.maximum(model2.predict(test), 0)
predict_rul_train = np.maximum(model2.predict(train), 0)

predict_rul_test = [i[0] for i in predict_rul_test.tolist()]
predict_rul_train = [i[0] for i in predict_rul_train.tolist()]

# Round dos valores preditos para valores inteiros.
predict_rul_test = [round(rul) for rul in predict_rul_test]
predict_rul_train = [round(rul) for rul in predict_rul_train]

data_result_train = pd.DataFrame([predict_rul_train, label_train]).T
data_result_test = pd.DataFrame([predict_rul_test, label_test]).T

coluns = ["PREDICTION", "REAL"]
data_result_train.columns = coluns
data_result_test.columns = coluns

min_index_train = data_result_train["REAL"].min()
idx = list(data_result_train[data_result_train["REAL"] == min_index_train].index)

d1_train = (
    data_result_train[idx[0] : idx[1]]
    .sort_values("REAL", ascending=False)
    .reset_index(drop=True)
)
d2_train = (
    data_result_train[idx[1] : idx[2]]
    .sort_values("REAL", ascending=False)
    .reset_index(drop=True)
)
d3_train = (
    data_result_train[idx[2] : idx[3]]
    .sort_values("REAL", ascending=False)
    .reset_index(drop=True)
)
d4_train = (
    data_result_train[idx[3] :]
    .sort_values("REAL", ascending=False)
    .reset_index(drop=True)
)

min_index_test = data_result_test["REAL"].min()
idx = list(data_result_test[data_result_test["REAL"] == min_index_test].index)

d1_test = (
    data_result_test[idx[0] : idx[1]]
    .sort_values("REAL", ascending=False)
    .reset_index(drop=True)
)
d2_test = (
    data_result_test[idx[1] : idx[2]]
    .sort_values("REAL", ascending=False)
    .reset_index(drop=True)
)
d3_test = (
    data_result_test[idx[2] :]
    .sort_values("REAL", ascending=False)
    .reset_index(drop=True)
)

dfs_train = [d1_train, d3_train, d4_train, d2_train]
dfs_test = [d1_test, d2_test, d3_test]

rejuste_index(dfs_train)
rejuste_index(dfs_test)

compare_plot(d1_train, d2_train, d3_train, d4_train, d1_test, d2_test, d3_test)
plt.savefig(f"images/resultados_epochs_{epochs}.png")

# TODO
# FAZER ESSE RUL DE FORMA PERCENETUAL VARIANDO ENTRE 0 E 1
df_train_scored = pd.concat(dfs_train, axis=0)
df_test_scored = pd.concat(dfs_test, axis=0)

scaler = MinMaxScaler()

df_train_scored["PREDICTION"] = df_train_scored["PREDICTION"] #scaler.fit_transform(df_train_scored["PREDICTION"].values.reshape(-1, 1)).reshape(-1)
df_train_scored["REAL"] = df_train_scored["REAL"]#scaler.transform(df_train_scored["REAL"].values.reshape(-1, 1)).reshape(-1)

df_test_scored["PREDICTION"] = df_test_scored["PREDICTION"] #scaler.fit_transform(df_test_scored["PREDICTION"].values.reshape(-1, 1)).reshape(-1)
df_test_scored["REAL"] = df_test_scored["REAL"]#scaler.transform(df_test_scored["REAL"].values.reshape(-1, 1)).reshape(-1)



def rmse(y_true, y_pred):
    return np.sqrt(((y_true - y_pred) ** 2).mean())


rmse_train = rmse(df_train_scored["PREDICTION"], df_train_scored["REAL"])
rmse_test = rmse(df_test_scored["PREDICTION"], df_test_scored["REAL"])

print("-- RMSE --/n")
print(f"rmse train: {rmse_train}")
print(f"rmse test: {rmse_test}")

# Calcular média dos valores reais
mean_real_train = df_train_scored["REAL"].mean()
mean_real_test = df_test_scored["REAL"].mean()

# Calcular RMSE percentual
rmse_percent_train = (rmse_train / mean_real_train) * 100
rmse_percent_test = (rmse_test / mean_real_test) * 100

print(f"RMSE percentual para conjunto de treino: {rmse_percent_train:.2f}%")
print(f"RMSE percentual para conjunto de teste: {rmse_percent_test:.2f}%")
# Out:
# Epoch 1/30
# 138/138 [==============================] - 6s 38ms/step - loss: 6.8418 - mse: 6.8418 - val_loss: 0.0485 - val_mse: 0.0485
# Epoch 2/30
# 138/138 [==============================] - 5s 37ms/step - loss: 0.0531 - mse: 0.0531 - val_loss: 0.0343 - val_mse: 0.0343
# Epoch 3/30
# 138/138 [==============================] - 5s 35ms/step - loss: 0.0338 - mse: 0.0338 - val_loss: 0.0456 - val_mse: 0.0456
# Epoch 4/30
# 138/138 [==============================] - 5s 35ms/step - loss: 0.0320 - mse: 0.0320 - val_loss: 0.0348 - val_mse: 0.0348
# Epoch 5/30
# 138/138 [==============================] - 5s 36ms/step - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0332 - val_mse: 0.0332
# Epoch 6/30
# 138/138 [==============================] - 5s 36ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0527 - val_mse: 0.0527
# Epoch 7/30
# 138/138 [==============================] - 5s 34ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0688 - val_mse: 0.0688
# Epoch 8/30
# 138/138 [==============================] - 5s 35ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0277 - val_mse: 0.0277
# Epoch 9/30
# 138/138 [==============================] - 5s 36ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0657 - val_mse: 0.0657
# Epoch 10/30
# 138/138 [==============================] - 5s 34ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0503 - val_mse: 0.0503
# Epoch 11/30
# 138/138 [==============================] - 5s 33ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 12/30
# 138/138 [==============================] - 5s 34ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0226 - val_mse: 0.0226
# Epoch 13/30
# 138/138 [==============================] - 5s 36ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0450 - val_mse: 0.0450
# Epoch 14/30
# 138/138 [==============================] - 5s 35ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0279 - val_mse: 0.0279
# Epoch 15/30
# 138/138 [==============================] - 5s 34ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0731 - val_mse: 0.0731
# Epoch 16/30
# 138/138 [==============================] - 5s 34ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0668 - val_mse: 0.0668
# Epoch 17/30
# 138/138 [==============================] - 5s 34ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0674 - val_mse: 0.0674
# Epoch 18/30
# 138/138 [==============================] - 5s 34ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0807 - val_mse: 0.0807
# Epoch 19/30
# 138/138 [==============================] - 5s 34ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0943 - val_mse: 0.0943
# Epoch 20/30
# 138/138 [==============================] - 5s 34ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0571 - val_mse: 0.0571
# Epoch 21/30
# 138/138 [==============================] - 5s 35ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.1000 - val_mse: 0.1000
# Epoch 22/30
# 138/138 [==============================] - 5s 35ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0462 - val_mse: 0.0462
# Epoch 23/30
# 138/138 [==============================] - 5s 35ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0689 - val_mse: 0.0689
# Epoch 24/30
# 138/138 [==============================] - 5s 35ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0217 - val_mse: 0.0217
# Epoch 25/30
# 138/138 [==============================] - 5s 35ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0704 - val_mse: 0.0704
# Epoch 26/30
# 138/138 [==============================] - 5s 35ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0492 - val_mse: 0.0492
# Epoch 27/30
# 138/138 [==============================] - 5s 35ms/step - loss: 9.6994e-04 - mse: 9.6994e-04 - val_loss: 0.0769 - val_mse: 0.0769
# Epoch 28/30
# 138/138 [==============================] - 5s 35ms/step - loss: 9.9491e-04 - mse: 9.9491e-04 - val_loss: 0.0613 - val_mse: 0.0613
# Epoch 29/30
# 138/138 [==============================] - 5s 37ms/step - loss: 8.7356e-04 - mse: 8.7356e-04 - val_loss: 0.0856 - val_mse: 0.0856
# Epoch 30/30
# 138/138 [==============================] - 5s 37ms/step - loss: 9.5169e-04 - mse: 9.5169e-04 - val_loss: 0.0539 - val_mse: 0.0539
# 190/190 [==============================] - 1s 7ms/step
# 269/269 [==============================] - 2s 7ms/step
# -- RMSE --/n
# rmse train: 0.32001738579532846
# rmse test: 0.3686026709980538
# RMSE percentual para conjunto de treino: 74.50%
# RMSE percentual para conjunto de teste: 98.01%

# %%
import pprint
import pandas as pd
import numpy as np
import os
import tqdm
import seaborn as sns
from tensorflow import keras
from tensorflow.keras.utils import plot_model
import tensorflow as tf
from scipy.signal import spectrogram
import matplotlib.pyplot as plt
from pipeline.utils import PrepareData, compare_plot
from pipeline import generate_model, get_initial_input


def rejuste_index(lista_dfs):
    """Rejusta o index para o plot do RUL."""
    for index, df in enumerate(lista_dfs):
        if index == 0:
            df['index'] = df.index.tolist()
        else:
            shape_anterior = lista_dfs[index-1]['index'].tail(1).values[0]
            df['index'] = np.arange(
                shape_anterior, df.shape[0] + shape_anterior)
        df['PREDICTION'] = df['PREDICTION'].apply(lambda x: 0 if x < 0 else x)


epochs = 2
train, test, label_train, label_test = get_initial_input()
model2, history = generate_model(
    train=train, label_train=label_train, epochs=epochs)


# plt.title('Learning Curves')
# plt.xlabel('Epochs')
# plt.ylabel('MSE')
# plt.plot(range(1, epochs+1), history.history['mse'], label='train')
# plt.plot(range(1, epochs+1), history.history['val_mse'], label='val')
# plt.xticks(range(1, epochs+1))
# plt.legend()
# plt.tight_layout()
# plt.savefig('images/mse_val_train.png')

predict_rul_test = np.maximum(model2.predict(test), 0)
predict_rul_train = np.maximum(model2.predict(train), 0)

predict_rul_test = [i[0] for i in predict_rul_test.tolist()]
predict_rul_train = [i[0] for i in predict_rul_train.tolist()]

# Round dos valores preditos para valores inteiros.
predict_rul_test = [round(rul) for rul in predict_rul_test]
predict_rul_train = [round(rul) for rul in predict_rul_train]

data_result_train = pd.DataFrame([predict_rul_train, label_train]).T
data_result_test = pd.DataFrame([predict_rul_test, label_test]).T

coluns = ['PREDICTION', 'REAL']
data_result_train.columns = coluns
data_result_test.columns = coluns

idx = list(
    data_result_train[data_result_train['REAL'] == 0.10000000149011612].index)

d1_train = data_result_train[idx[0]:idx[1]].sort_values(
    'REAL', ascending=False).reset_index(drop=True)
d2_train = data_result_train[idx[1]:idx[2]].sort_values(
    'REAL', ascending=False).reset_index(drop=True)
d3_train = data_result_train[idx[2]:idx[3]].sort_values(
    'REAL', ascending=False).reset_index(drop=True)
d4_train = data_result_train[idx[3]:].sort_values(
    'REAL', ascending=False).reset_index(drop=True)

idx = list(data_result_test[data_result_test['REAL']
           == 0.10000000149011612].index)

d1_test = data_result_test[idx[0]:idx[1]].sort_values(
    'REAL', ascending=False).reset_index(drop=True)
d2_test = data_result_test[idx[1]:idx[2]].sort_values(
    'REAL', ascending=False).reset_index(drop=True)
d3_test = data_result_test[idx[2]:].sort_values(
    'REAL', ascending=False).reset_index(drop=True)

dfs_train = [d1_train, d3_train, d4_train, d2_train]
dfs_test = [d1_test, d2_test, d3_test]

rejuste_index(dfs_train)
rejuste_index(dfs_test)

compare_plot(d1_train, d2_train, d3_train, d4_train, d1_test, d2_test, d3_test)
plt.savefig(f'images/resultados_epochs_{epochs}_scaler.png')

# TODO
# FAZER ESSE RUL DE FORMA PERCENETUAL VARIANDO ENTRE 0 E 1
df_train_scored = pd.concat(dfs_train, axis=0)
df_test_scored = pd.concat(dfs_test, axis=0)


def rmse(y_true, y_pred):
    return np.sqrt(((y_true - y_pred) ** 2).mean())


rmse_train = rmse(df_train_scored['PREDICTION'], df_train_scored['REAL'])
rmse_test = rmse(df_test_scored['PREDICTION'], df_test_scored['REAL'])

print('-- RMSE --/n')
print(f'rmse train: {rmse_train}')
print(f'rmse test: {rmse_test}')
# Out:
# Epoch 1/50
# 138/138 [==============================] - 24s 159ms/step - loss: 40.2144 - mse: 40.2144 - val_loss: 0.0488 - val_mse: 0.0488
# Epoch 2/50
# 138/138 [==============================] - 22s 158ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0264 - val_mse: 0.0264
# Epoch 3/50
# 138/138 [==============================] - 22s 157ms/step - loss: 0.0178 - mse: 0.0178 - val_loss: 0.0252 - val_mse: 0.0252
# Epoch 4/50
# 138/138 [==============================] - 22s 158ms/step - loss: 0.0179 - mse: 0.0179 - val_loss: 0.0263 - val_mse: 0.0263
# Epoch 5/50
# 138/138 [==============================] - 22s 159ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0259 - val_mse: 0.0259
# Epoch 6/50
# 138/138 [==============================] - 22s 158ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0712 - val_mse: 0.0712
# Epoch 7/50
# 138/138 [==============================] - 27s 194ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0617 - val_mse: 0.0617
# Epoch 8/50
# 138/138 [==============================] - 23s 164ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0672 - val_mse: 0.0672
# Epoch 9/50
# 138/138 [==============================] - 23s 166ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0486 - val_mse: 0.0486
# Epoch 10/50
# 138/138 [==============================] - 23s 164ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0655 - val_mse: 0.0655
# Epoch 11/50
# 138/138 [==============================] - 22s 158ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0826 - val_mse: 0.0826
# Epoch 12/50
# 138/138 [==============================] - 22s 163ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0739 - val_mse: 0.0739
# Epoch 13/50
# 138/138 [==============================] - 27s 199ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0683 - val_mse: 0.0683
# Epoch 14/50
# 138/138 [==============================] - 23s 166ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0611 - val_mse: 0.0611
# Epoch 15/50
# 138/138 [==============================] - 25s 178ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0832 - val_mse: 0.0832
# Epoch 16/50
# 138/138 [==============================] - 23s 164ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0633 - val_mse: 0.0633
# Epoch 17/50
# 138/138 [==============================] - 24s 176ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0944 - val_mse: 0.0944
# Epoch 18/50
# 138/138 [==============================] - 17s 124ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0668 - val_mse: 0.0668
# Epoch 19/50
# 138/138 [==============================] - 24s 173ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.1161 - val_mse: 0.1161
# Epoch 20/50
# 138/138 [==============================] - 21s 150ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.1089 - val_mse: 0.1089
# Epoch 21/50
# 138/138 [==============================] - 24s 177ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0935 - val_mse: 0.0935
# 190/190 [==============================] - 5s 27ms/step
# 269/269 [==============================] - 7s 27ms/step
# -- RMSE --/n
# rmse train: 0.37353030884713695
# rmse test: 0.3767329498786901

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(d1_train["index"], d1_train["PREDICTION"])
